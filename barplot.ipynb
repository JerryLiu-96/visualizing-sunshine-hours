# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import csv

# %%
import pandas as pd

# %%
df=pd.read_csv('assets/sunshine.csv')

# %%
df
# Out:
#        city         lon        lat month  monthnum  sunshine
# 0   Chicago  -87.623177  41.881832   Jan         0       135
# 1   Chicago  -87.623177  41.881832   Feb         1       136
# 2   Chicago  -87.623177  41.881832   Mar         2       187
# 3   Chicago  -87.623177  41.881832   Apr         3       215
# 4   Chicago  -87.623177  41.881832   May         4       281
# ..      ...         ...        ...   ...       ...       ...
# 67  Seattle -122.335167  47.608013   Aug         7       281
# 68  Seattle -122.335167  47.608013   Sep         8       221
# 69  Seattle -122.335167  47.608013   Oct         9       142
# 70  Seattle -122.335167  47.608013   Nov        10        72
# 71  Seattle -122.335167  47.608013   Dec        11        52
#
# [72 rows x 6 columns]

# %%
#print the 20th row of the dataframe
df.iloc[70]
# Out:
# city           Seattle
# lon        -122.335167
# lat          47.608013
# month              Nov
# monthnum            10
# sunshine            72
# Name: 70, dtype: object

# %%
unique_cities = df['city'].unique()
print(unique_cities)
# Out:
# ['Chicago' 'Houston' 'Miami' 'New York' 'San Francisco' 'Seattle']

# %%
df['sunshine']
# Out:
# 0     135
# 1     136
# 2     187
# 3     215
# 4     281
#      ...
# 67    281
# 68    221
# 69    142
# 70     72
# 71     52
# Name: sunshine, Length: 72, dtype: int64

# %%
max_sunshine = df['sunshine'].max()
print(max_sunshine)
# Out:
# 330

# %%
type(df['sunshine'])
# Out:
# pandas.core.series.Series

# %%
from matplotlib.colors import LinearSegmentedColormap
# Define a gradient color map
cmap = LinearSegmentedColormap.from_list('mycmap', [(0, '#feedde'), (0.25, '#fdbe85'), (0.5,'#fd8d3c'),(0.75,'#e6550d'),(1, '#a63603')])

# %%
330*0.75
# Out:
# 247.5

# %%
# create a dataset
height = np.array(df['sunshine'][0:12])
month = np.array(df['month'][0:12])
x_pos = np.arange(len(month))

# Create the bar plot with gradient colors
fig, ax = plt.subplots()
bars = ax.bar(month, height, color=cmap(height / max_sunshine))

# Create names on the x-axis
plt.xticks(x_pos, month)
plt.title('Chicago',fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Hours of Sunshine')
plt.ylim(0, 330)

# Add a color bar to show the mapping of values to colors
cbar=fig.colorbar(plt.cm.ScalarMappable(norm=None, cmap=cmap), ax=ax)
cbar.set_ticks([0, 0.25,0.5,0.75, 1.0])
cbar.set_ticklabels(['0', '82.5','155','247.5', '330'])

# Show graph

fig.set_dpi(300)

plt.savefig("img/output_chi.png",format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# create a dataset
height = df['sunshine'][12:24]
bars = df['month'][0:12]
x_pos = np.arange(len(bars))

# Create the bar plot with gradient colors
fig, ax = plt.subplots()
bars = ax.bar(month, height, color=cmap(height / max_sunshine))

# Create names on the x-axis
plt.xticks(x_pos, month)
plt.title('Houston',fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Hours of Sunshine')
plt.ylim(0, 330)

# Add a color bar to show the mapping of values to colors
cbar=fig.colorbar(plt.cm.ScalarMappable(norm=None, cmap=cmap), ax=ax)
cbar.set_ticks([0, 0.25,0.5,0.75, 1.0])
cbar.set_ticklabels(['0', '82.5','155','247.5', '330'])

# Show graph

fig.set_dpi(300)

plt.savefig("img/output_hou.png",format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# create a dataset
height = df['sunshine'][24:36]
bars = df['month'][0:12]
x_pos = np.arange(len(bars))

# Create the bar plot with gradient colors
fig, ax = plt.subplots()
bars = ax.bar(month, height, color=cmap(height / max_sunshine))

# Create names on the x-axis
plt.xticks(x_pos, month)
plt.title('Miami',fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Hours of Sunshine')
plt.ylim(0, 330)

# Add a color bar to show the mapping of values to colors
cbar=fig.colorbar(plt.cm.ScalarMappable(norm=None, cmap=cmap), ax=ax)
cbar.set_ticks([0, 0.25,0.5,0.75, 1.0])
cbar.set_ticklabels(['0', '82.5','155','247.5', '330'])

# Show graph

fig.set_dpi(300)

plt.savefig("img/output_mia.png",format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# create a dataset
height = df['sunshine'][36:48]
bars = df['month'][0:12]
x_pos = np.arange(len(bars))

# Create the bar plot with gradient colors
fig, ax = plt.subplots()
bars = ax.bar(month, height, color=cmap(height / max_sunshine))

# Create names on the x-axis
plt.xticks(x_pos, month)
plt.title('New York',fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Hours of Sunshine')
plt.ylim(0, 330)

# Add a color bar to show the mapping of values to colors
cbar=fig.colorbar(plt.cm.ScalarMappable(norm=None, cmap=cmap), ax=ax)
cbar.set_ticks([0, 0.25,0.5,0.75, 1.0])
cbar.set_ticklabels(['0', '82.5','155','247.5', '330'])

# Show graph

fig.set_dpi(300)

plt.savefig("img/output_ny.png",format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# create a dataset
height = df['sunshine'][48:60]
bars = df['month'][0:12]
x_pos = np.arange(len(bars))

# Create the bar plot with gradient colors
fig, ax = plt.subplots()
bars = ax.bar(month, height, color=cmap(height / max_sunshine))

# Create names on the x-axis
plt.xticks(x_pos, month)
plt.title('San Francisco',fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Hours of Sunshine')
plt.ylim(0, 330)

# Add a color bar to show the mapping of values to colors
cbar=fig.colorbar(plt.cm.ScalarMappable(norm=None, cmap=cmap), ax=ax)
cbar.set_ticks([0, 0.25,0.5,0.75, 1.0])
cbar.set_ticklabels(['0', '82.5','155','247.5', '330'])

# Show graph
fig.set_dpi(300)

plt.savefig("img/output_sf.png",format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# create a dataset
height = df['sunshine'][60:72]
bars = df['month'][0:12]
x_pos = np.arange(len(bars))

# Create the bar plot with gradient colors
fig, ax = plt.subplots()
bars = ax.bar(month, height, color=cmap(height / max_sunshine))

# Create names on the x-axis
plt.xticks(x_pos, month)
plt.title('Seattle',fontsize = 20)
plt.xlabel('Month')
plt.ylabel('Hours of Sunshine')
plt.ylim(0, 330)

# Add a color bar to show the mapping of values to colors
cbar=fig.colorbar(plt.cm.ScalarMappable(norm=None, cmap=cmap), ax=ax)
cbar.set_ticks([0, 0.25,0.5,0.75, 1.0])
cbar.set_ticklabels(['0', '82.5','155','247.5', '330'])

# Show graph
fig.set_dpi(300)

plt.savefig("img/output_sea.png",format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
"""from matplotlib.colors import LinearSegmentedColormap
# Define a gradient color map
cmap = LinearSegmentedColormap.from_list('mycmap', [(0, '#deebf7'), (0.5, '#9ecae1'), (1, '#3182bd')])

# Generate some random data for the bar plot
x = np.arange(10)
y = np.random.rand(10) * 10

# Create the bar plot with gradient colors
fig, ax = plt.subplots()
bars = ax.bar(x, y, color=cmap(y / max(y)))

# Add a color bar to show the mapping of values to colors
cbar=fig.colorbar(plt.cm.ScalarMappable(norm=None, cmap=cmap), ax=ax)
cbar.set_ticks([0, 0.5, 1.0])
cbar.set_ticklabels(['Low', 'Medium', 'High'])

plt.show()"""

# %%
y
# Out:
# array([2.28128392, 2.77807102, 5.59771912, 2.64873015, 5.5470628 ,
#        4.74477146, 2.80846658, 5.88803351, 7.49855138, 0.78601123])

# %%
type(y)
# Out:
# numpy.ndarray

# %%
bars
# Out:
# <BarContainer object of 10 artists>

# %%
np.array(height)
# Out:
# array([ 69, 108, 178, 207, 253, 268, 312, 281, 221, 142,  72,  52])

# %%
type(np.array(height))
# Out:
# numpy.ndarray

# %%
df
# Out:
#        city         lon        lat month  monthnum  sunshine
# 0   Chicago  -87.623177  41.881832   Jan         0       135
# 1   Chicago  -87.623177  41.881832   Feb         1       136
# 2   Chicago  -87.623177  41.881832   Mar         2       187
# 3   Chicago  -87.623177  41.881832   Apr         3       215
# 4   Chicago  -87.623177  41.881832   May         4       281
# ..      ...         ...        ...   ...       ...       ...
# 67  Seattle -122.335167  47.608013   Aug         7       281
# 68  Seattle -122.335167  47.608013   Sep         8       221
# 69  Seattle -122.335167  47.608013   Oct         9       142
# 70  Seattle -122.335167  47.608013   Nov        10        72
# 71  Seattle -122.335167  47.608013   Dec        11        52
#
# [72 rows x 6 columns]

# %%
df['sunshine'][0:12]
# Out:
# 0     135
# 1     136
# 2     187
# 3     215
# 4     281
# 5     311
# 6     318
# 7     283
# 8     226
# 9     193
# 10    113
# 11    106
# Name: sunshine, dtype: int64

# %%
list(df['sunshine'][0:12])
# Out:
# [135, 136, 187, 215, 281, 311, 318, 283, 226, 193, 113, 106]

# %%
import matplotlib.pyplot as plt
import pandas as pd

import matplotlib as mpl

# Set the default figure size
#mpl.rcParams['figure.figsize'] = [10, 6]

#plt.figure(figsize=(10,6))

# Create a DataFrame with the GDP data
data = {'Chicago': list(df['sunshine'][0:12]),
        'Houston': list(df['sunshine'][12:24]),
        'Miami': list(df['sunshine'][24:36]),
        'New York': list(df['sunshine'][36:48]),
        'San Francisco': list(df['sunshine'][48:60]),
        'Seattle': list(df['sunshine'][60:72])}
dfm = pd.DataFrame(data, index=["Jan", "Feb", "Mar", "Apr", "May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"])

# Create a line plot of the GDP data
plt.plot(dfm.index, dfm['Chicago'], label='Chicago')
plt.plot(dfm.index, dfm['Houston'], label='Houston')
plt.plot(dfm.index, dfm['Miami'], label='Miami')
plt.plot(dfm.index, dfm['New York'], label='New York')
plt.plot(dfm.index, dfm['San Francisco'], label='San Francisco')
plt.plot(dfm.index, dfm['Seattle'], label='Seattle')

# Set the plot title and axis labels
plt.title('Average Hours of Sunshine by month in US Cities')
plt.xlabel('Month')
plt.ylabel('Sunshine (hours)')

# Add a legend to the plot
plt.legend()

# Show graph
fig.set_dpi(300)

#fig.patch.set_facecolor('grey')

fig.patch.set_alpha(0.5)
plt.gca().xaxis.grid(True)

plt.savefig("img/output_compare.png",format='png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
